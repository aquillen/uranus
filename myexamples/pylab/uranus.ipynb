# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %load_ext autoreload  
# %autoreload 2
from orbsubs_ur import *

# %%
fileroot = "../uranus/w3"  
numberpm=2  # number of point masses
plt_cols(fileroot,numberpm,0,0,5,2)  # first 0 is saveit, second one is tmax
# Out:
# ../uranus/w3_ext.txt
# ../uranus/w3_pm0.txt
# ../uranus/w3_pm1.txt
# kk= 2

# %%
fileroot = "../uranus/w1"  
numberpm=2  # number of point masses
plt_cols(fileroot,numberpm,0,0,5,2)
# Out:
# ../uranus/w1_ext.txt
# ../uranus/w1_pm0.txt
# ../uranus/w1_pm1.txt
# kk= 2

# %%
fileroot = "../uranus/u1"  
numberpm=2  # number of point masses
plt_cols(fileroot,numberpm,0,0,5,2)  # first 0 is saveit, second one is tmax
# Out:
# ../uranus/u1_ext.txt
# ../uranus/u1_pm0.txt
# ../uranus/u1_pm1.txt
# kk= 2

# %%
fileroot = "../uranus/u2"  
numberpm=2  # number of point masses
plt_cols(fileroot,numberpm,0,0,5,2)  # first 0 is saveit, second one is tmax
# Out:
# ../uranus/u2_ext.txt
# ../uranus/u2_pm0.txt
# ../uranus/u2_pm1.txt
# kk= 2

# %%
fileroot = "../uranus/u3"  
numberpm=2  # number of point masses
plt_cols(fileroot,numberpm,0,0,5,2)  # first 0 is saveit, second one is tmax
# Out:
# ../uranus/u3_ext.txt
# ../uranus/u3_pm0.txt
# ../uranus/u3_pm1.txt
# kk= 1
